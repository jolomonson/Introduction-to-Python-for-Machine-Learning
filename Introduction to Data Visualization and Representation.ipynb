# %%
print('Data Visualization and Representation')
# Out:
# Data Visualization and Representation

# %%
# importing libraries for visualization and plotting
import pandas as pd
import matplotlib.pyplot as plt #pip install matplotlib
import seaborn as sns #pip install seaborn

# %%
plt.figure(figsize=(7,4))#- This specifies the size of the graph you're plotting 
plt.xticks(rotation=10)#- The type of style of text in x axis
plt.yticks(rotation=10)#- The type of style of text in y axis
fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU','MWDTH', 'MWHTH', 'TON'],
                          'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
sns.barplot(data=fuel_unit, x='unit', y='count') #- Specifying the axis to plot data and the dataframe to be used
# Out:
# <AxesSubplot:xlabel='unit', ylabel='count'>

# %%
print('Because of the extreme range of the values for the fuel unit, we can plot the barchart by taking the logarithm of the y-axis as follows:')
g = sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale("log")
g.set_ylim(1, 12000)
plt.xlabel('Fuel Unit')
# Out:
# Because of the extreme range of the values for the fuel unit, we can plot the barchart by taking the logarithm of the y-axis as follows:
# Text(0.5, 0, 'Fuel Unit')

# %%
# Select a sample of the dataset
sample_df = fuel_unit.sample(n=50, random_state=4, replace=True)
#sample_df.head()
sns.regplot(x=sample_df["unit"], y=sample_df["count"], fit_reg=False)
# Out:
# <AxesSubplot:xlabel='unit', ylabel='count'>

# %%
#Box plot
sns.boxplot(x="unit", y="count", palette=["m", "g"], data=fuel_unit)
# KDE plot
sns.kdeplot(data=fuel_unit, y='count', shade=True, color="b")
# Out:
# <AxesSubplot:xlabel='unit', ylabel='count'>
