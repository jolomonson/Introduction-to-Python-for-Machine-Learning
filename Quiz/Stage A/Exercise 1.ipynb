# %%
import pandas as pd
df = pd.read_csv('dataset/FoodBalanceSheets.csv', encoding='latin-1')
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
print('Question 1')
print('Total Sum of AnimalFat produced in 2014 and 2017 respectively')
AnimalFatSum = df.groupby(['Item'])['Y2014','Y2015'].count()
print(AnimalFatSum)
print('groupby() is basically a form of joining/group multiple columns using a central column provided as a parameter')
# Out:
# Question 1
# Total Sum of AnimalFat produced in 2014 and 2017 respectively
# C:\Users\ADEKANYE\AppData\Local\Temp\ipykernel_10052\1109957534.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   AnimalFatSum = df.groupby(['Item'])['Y2014','Y2015'].count()
#                      Y2014  Y2015
# Item
# Alcohol, Non-Food      275    271
# Alcoholic Beverages    562    559
# Animal Products        135    135
# Animal fats            635    633
# Apples and products    510    511
# ...                    ...    ...
# Vegetables, Other      575    573
# Vegetal Products       135    135
# Wheat and products     645    648
# Wine                   491    490
# Yams                   318    330
#
# [119 rows x 2 columns]
# groupby() is basically a form of joining/group multiple columns using a central column provided as a parameter
